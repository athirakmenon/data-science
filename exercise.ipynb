# %%
import pandas as pd
import matplotlib.pyplot as plt


bcs = pd.read_csv("BCS_ann.csv")
bp = pd.read_csv("BP_ann.csv")
tsco = pd.read_csv("TSCO_ann.csv")
vod = pd.read_csv("VOD_ann.csv")

plt.figure()

plt.subplot(2,2,1)
plt.hist(bcs["ann_return"], label="Barclays")

plt.legend()
plt.ylabel("N")


plt.subplot(2,2,2)
plt.hist(bp["ann_return"], label="BP")

plt.legend()
plt.ylabel("N")

plt.subplot(2,2,3)
plt.hist(tsco["ann_return"], label="TSCO")

plt.legend()
plt.xlabel("returns (%)")
plt.ylabel("N")

plt.subplot(2,2,4)
plt.hist(vod["ann_return"], label="VOD")

plt.legend()
plt.xlabel("returns (%)")
plt.ylabel("N")
plt.show()





# histograms of two companies

plt.figure()

plt.hist(tsco["ann_return"], label="TSCO",alpha=0.7,density=True)
plt.hist(vod["ann_return"], label="VOD",alpha=0.7,density=True)

plt.legend()
plt.xlabel("returns (%)")
plt.ylabel("N")
plt.show()





plt.figure()

plt.boxplot([bcs["ann_return"], bp["ann_return"],
           tsco["ann_return"], vod["ann_return"]],
           labels=["Barclays","Bp","Tesco","Vodaphone"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x274e49f9450>,
#   <matplotlib.lines.Line2D at 0x274e49f8460>,
#   <matplotlib.lines.Line2D at 0x274e49fb3d0>,
#   <matplotlib.lines.Line2D at 0x274e49fb250>,
#   <matplotlib.lines.Line2D at 0x274e4864220>,
#   <matplotlib.lines.Line2D at 0x274e48649a0>,
#   <matplotlib.lines.Line2D at 0x274e4865f30>,
#   <matplotlib.lines.Line2D at 0x274e4864ca0>],
#  'caps': [<matplotlib.lines.Line2D at 0x274e49f8040>,
#   <matplotlib.lines.Line2D at 0x274e49fbd30>,
#   <matplotlib.lines.Line2D at 0x274e49f9f30>,
#   <matplotlib.lines.Line2D at 0x274e49f83d0>,
#   <matplotlib.lines.Line2D at 0x274e4866470>,
#   <matplotlib.lines.Line2D at 0x274e4865540>,
#   <matplotlib.lines.Line2D at 0x274e4864d30>,
#   <matplotlib.lines.Line2D at 0x274e4867670>],
#  'boxes': [<matplotlib.lines.Line2D at 0x274e49fa890>,
#   <matplotlib.lines.Line2D at 0x274e49fbaf0>,
#   <matplotlib.lines.Line2D at 0x274e4864580>,
#   <matplotlib.lines.Line2D at 0x274e4865930>],
#  'medians': [<matplotlib.lines.Line2D at 0x274e49fb370>,
#   <matplotlib.lines.Line2D at 0x274e49fb430>,
#   <matplotlib.lines.Line2D at 0x274e4866080>,
#   <matplotlib.lines.Line2D at 0x274e4b315a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x274e49f93c0>,
#   <matplotlib.lines.Line2D at 0x274e4867640>,
#   <matplotlib.lines.Line2D at 0x274e48671c0>,
#   <matplotlib.lines.Line2D at 0x274e4b309a0>],
#  'means': []}

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


cap = np.array([33367,68785,20979,29741])
stocks = ["Barclays","Bp",
          "Tesco","Vodaphone"]


ftse = 1814000
cap = cap/ftse

plt.figure()
plt.pie(cap, labels=stocks, normalize=False)
plt.show()

print(cap)
# Out:
# [0.01839416 0.03791896 0.01156505 0.01639526]
